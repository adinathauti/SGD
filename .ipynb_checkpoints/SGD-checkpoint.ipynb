# %% [markdown]
# ## Import packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import operator as op
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Create some random numbers.

# %%
X = np.array(range(1, 25))
Y = np.array([ele*np.exp(1)-10*np.random.randn() for ele in X])
X = X.reshape(-1, 1)
Y = Y.reshape(-1, 1)
plt.plot(X, Y, 'b')
plt.show()

# %% [markdown]
# ## Plot predicted line(with params initialized as 0).

# %%
m = np.random.randint(1,100)
c = np.random.randint(1,100)
print 'M={} , c={}'.format(m, c)
Y_pred = X*m + c
plt.plot(X, Y,'b')
plt.plot(X, Y_pred, 'r')
plt.show()
# Out:
# M=96 , c=88

# %% [markdown]
# ## Define RSS and gradient functions.

# %%
def RSS(Y, Y_pred):
    diff = Y - Y_pred
    rss = np.sqrt(diff * diff)
    return sum(rss)

# %%
def grad_m(x, y):
    return (-1.0/len(x))*x*(y-(m*x+c))

# %%
def grad_c(x, y):
    return  (-1.0/len(x))*(y-(m*x+c))

# %% [markdown]
# ## Initialize rate and no. of iterations.

# %%
eta = 0.0001
iters = 10000
old_rss = RSS(Y, Y_pred)

# %% [markdown]
# ## Plot before SGD.

# %%
plt.scatter(X, Y, c='g')
plt.plot(X, Y_pred, 'r')
plt.show()

# %% [markdown]
# ## Perform SGD to reduce RSS within specified no. of iterations.

# %%
while RSS(Y, Y_pred)>5:
    iters -= 1
    if iters == 0:
        print 'Ran out of iters'
        break
    #print RSS(Y,Y_pred)
    for idx,ele in enumerate(X):
        m = m-(eta)*grad_m(ele, Y[idx])
        c = c-(eta)*grad_c(ele, Y[idx])
        Y_pred = m*X + c
# Out:
# Ran out of iters

# %% [markdown]
# ## Plot after SGD.

# %%
new_rss = RSS(Y, Y_pred)
plt.scatter(X, Y, c='g')
plt.plot(X, Y_pred, 'r')
plt.show()
print("Reduced RSS from:{} to:{}".format(old_rss, new_rss))
# Out:
# Reduced RSS from:[ 30066.18596371] to:[ 160.9953115]

# %% [markdown]
# ## Comparing our approach to that of SKLearn.

# %%
lr = LinearRegression(fit_intercept=True)
lr.fit(X, Y)
Y_pred_skl = lr.predict(X)
plt.figure(figsize=(10,8))
plt.scatter(X, Y, c='g')
plt.plot(X, Y_pred, c='r', label='computed')
plt.plot(X, Y_pred_skl, 'b', label='SKLearn')
plt.legend()
plt.show()
